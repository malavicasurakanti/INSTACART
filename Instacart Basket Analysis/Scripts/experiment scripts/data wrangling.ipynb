# %%
import pandas as pd
import numpy as np
import os

# %%
# Set the path to the directory where your file is located
path = '/Users/malavica/Library/CloudStorage/OneDrive-Personal/Documents/careerfoundry/achviement 4/4'

# Construct the full file path
file_path = os.path.join(path, 'orders.csv')  # Assuming the file is directly under the '4' folder

# Check if the file exists and then read it
if os.path.exists(file_path):
    df_ords = pd.read_csv(file_path, index_col=False)
    print("File loaded successfully.")
else:
    print("File not found. Please check the file name and path.")
# Out:
# File loaded successfully.

# %%
df.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
path = '/Users/malavica/Library/CloudStorage/OneDrive-Personal/Documents/careerfoundry/achviement 4/4'

# Construct the full file path
file_path = os.path.join(path, 'products.csv')  # Assuming the file is directly under the '4' folder

# Check if the file exists and then read it
if os.path.exists(file_path):
    df_prods = pd.read_csv(file_path, index_col=False)
    print("File loaded successfully.")
else:
    print("File not found. Please check the file name and path.")
# Out:
# File loaded successfully.

# %%
df.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
df_ords.drop(columns = ['eval_set'])# dropping the eval_set
# Out:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0         2539329        1             1          2                  8
# 1         2398795        1             2          3                  7
# 2          473747        1             3          3                 12
# 3         2254736        1             4          4                  7
# 4          431534        1             5          4                 15
# ...           ...      ...           ...        ...                ...
# 3421078   2266710   206209            10          5                 18
# 3421079   1854736   206209            11          4                 10
# 3421080    626363   206209            12          1                 12
# 3421081   2977660   206209            13          1                 12
# 3421082    272231   206209            14          6                 14
#
#          days_since_prior_order
# 0                           NaN
# 1                          15.0
# ...

# %%
df_ords.rename(columns = {'order_dow':'order-day_of_day'}, inplace = True) # renaming the columns

# %%
df_ords.head()
# Out:
#    order_id  user_id eval_set  order_number  order-day_of_day  \
# 0   2539329        1    prior             1                 2
# 1   2398795        1    prior             2                 3
# 2    473747        1    prior             3                 3
# 3   2254736        1    prior             4                 4
# 4    431534        1    prior             5                 4
#
#    order_hour_of_day  days_since_prior_order
# 0                  8                     NaN
# 1                  7                    15.0
# 2                 12                    21.0
# 3                  7                    29.0
# 4                 15                    28.0

# %%
df_ords['order_id']= df_ords['order_id'].astype('str') # changing the data type

# %%
df_ords['order_id']. dtype
# Out:
# dtype('O')

# %%
#Imported Data set departments.csv
df_dep=pd.read_csv(os.path.join(path,'departments.csv'), index_col = False)
path = '/Users/malavica/Library/CloudStorage/OneDrive-Personal/Documents/careerfoundry/achviement 4/4'

# %%
df_dep.head()
# Out:
#   department_id       1      2       3        4        5              6  \
# 0    department  frozen  other  bakery  produce  alcohol  international
#
#            7     8                9  ...            12      13         14  \
# 0  beverages  pets  dry goods pasta  ...  meat seafood  pantry  breakfast
#
#              15          16         17      18      19    20       21
# 0  canned goods  dairy eggs  household  babies  snacks  deli  missing
#
# [1 rows x 22 columns]

# %%
df_dep.T # transposing columns into rows
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
df_dep_t = df_dep.T

# %%
df_dep_t
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
new_header = df_dep_t.iloc[0] # assigning new header

# %%
new_header
# Out:
# 0    department
# Name: department_id, dtype: object

# %%
df_dep_t_new = df_dep_t[1:]

# %%
df_dep_t_new
# Out:
#                   0
# 1            frozen
# 2             other
# 3            bakery
# 4           produce
# 5           alcohol
# 6     international
# 7         beverages
# 8              pets
# 9   dry goods pasta
# 10             bulk
# 11    personal care
# 12     meat seafood
# 13           pantry
# 14        breakfast
# 15     canned goods
# 16       dairy eggs
# 17        household
# 18           babies
# 19           snacks
# 20             deli
# 21          missing

# %%
df_dep_t_new.columns= new_header

# %%
df_dep_t_new
# Out:
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
data_dict = df_dep_t_new.to_dict('index') #addig df_dep into data_dict

# %%
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %%
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
print(data_dict.get('19'))
# Out:
# {'department': 'snacks'}

# %%
df_prods['department_id']==19
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 49688    False
# 49689    False
# 49690    False
# 49691    False
# 49692    False
# Name: department_id, Length: 49693, dtype: bool

# %%
df_snacks=df_prods[df_prods['department_id']==19] # creating subset of department _id 19 containing snacks

# %%
df_snacks
# Out:
#        product_id                                   product_name  aisle_id  \
# 0               1                     Chocolate Sandwich Cookies        61
# 15             16                  Mint Chocolate Flavored Syrup       103
# 24             25        Salted Caramel Lean Protein & Fiber Bar         3
# 31             32                  Nacho Cheese White Bean Chips       107
# 40             41    Organic Sourdough Einkorn Crackers Rosemary        78
# ...           ...                                            ...       ...
# 49666       49662                   Bacon Cheddar Pretzel Pieces       107
# 49669       49665  Super Dark Coconut Ash & Banana Chocolate Bar        45
# 49670       49666                  Ginger Snaps Snacking Cookies        61
# 49675       49671                           Milk Chocolate Drops        45
# 49683       49679                        Famous Chocolate Wafers        61
#
#        department_id  prices
# 0                 19     5.8
# ...

# %%
df_ords['order_id'] = df_ords['order_id'].astype('str') # changing data type

# %%
df_ords['order_id'].dtype
# Out:
# dtype('O')

# %%
df_ords.head()
# Out:
#   order_id  user_id eval_set  order_number  order-day_of_day  \
# 0  2539329        1    prior             1                 2
# 1  2398795        1    prior             2                 3
# 2   473747        1    prior             3                 3
# 3  2254736        1    prior             4                 4
# 4   431534        1    prior             5                 4
#
#    order_hour_of_day  days_since_prior_order
# 0                  8                     NaN
# 1                  7                    15.0
# 2                 12                    21.0
# 3                  7                    29.0
# 4                 15                    28.0

# %%
df_ords = df_ords.drop(columns=['eval_set']) #dropping eval_set permanently

# %%
df_ords.head()
# Out:
#   order_id  user_id  order_number  order-day_of_day  order_hour_of_day  \
# 0  2539329        1             1                 2                  8
# 1  2398795        1             2                 3                  7
# 2   473747        1             3                 3                 12
# 3  2254736        1             4                 4                  7
# 4   431534        1             5                 4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
df_ords['order_hour_of_day'].value_counts() # value count in the column order_hour_of_day
# Out:
# order_hour_of_day
# 10    288418
# 11    284728
# 15    283639
# 14    283042
# 13    277999
# 12    272841
# 16    272553
# 9     257812
# 17    228795
# 18    182912
# 8     178201
# 19    140569
# 20    104292
# 7      91868
# 21     78109
# 22     61468
# 23     40043
# 6      30529
# 0      22758
# 1      12398
# 5       9569
# 2       7539
# 4       5527
# 3       5474
# Name: count, dtype: int64

# %%
print(data_dict.get('4')) # to know is 4 from the output line 62
# Out:
# {'department': 'produce'}

# %%
df_breakfast=df_prods[df_prods['department_id']==14] # breakfast in department_id

# %%
df_breakfast.head()
# Out:
#      product_id                                      product_name  aisle_id  \
# 27           28                                 Wheat Chex Cereal       121
# 33           34                                               NaN       121
# 67           68                           Pancake Mix, Buttermilk       130
# 89           90                                      Smorz Cereal       121
# 210         211  Gluten Free Organic Cereal Coconut Maple Vanilla       130
#
#      department_id  prices
# 27              14    10.1
# 33              14    12.2
# 67              14    13.7
# 89              14     3.9
# 210             14     3.6

# %%
df_dinner_party =df_prods.loc[df_prods['department_id'].isin([5,7,12,20])] # dinner in department_id

# %%
df_dinner_party.head(50)
# Out:
#      product_id                                       product_name  aisle_id  \
# 2             3               Robust Golden Unsweetened Oolong Tea        94
# 6             7                     Pure Coconut Water With Orange        98
# 9            10     Sparkling Orange Juice & Prickly Pear Beverage       115
# 10           11                                  Peach Mango Juice        31
# 16           17                                  Rendered Duck Fat        35
# 19           20     Pomegranate Cranberry & Aloe Vera Enrich Drink        98
# 22           23                             Organic Turkey Burgers        49
# 34           35     Italian Herb Porcini Mushrooms Chicken Sausage       106
# 38           39           Daily Tangerine Citrus Flavored Beverage        64
# 39           40  Beef Hot Links Beef Smoked Sausage With Chile ...       106
# 43           44                        Sparkling Raspberry Seltzer       115
# ...

# %%
df_dinner_party.shape
# Out:
# (7650, 5)

# %%
df_user_id = df_ords[df_ords['user_id']==1] # extracting the information of user_id = 1

# %%
df_user_id.head(50)
# Out:
#    order_id  user_id  order_number  order-day_of_day  order_hour_of_day  \
# 0   2539329        1             1                 2                  8
# 1   2398795        1             2                 3                  7
# 2    473747        1             3                 3                 12
# 3   2254736        1             4                 4                  7
# 4    431534        1             5                 4                 15
# 5   3367565        1             6                 2                  7
# 6    550135        1             7                 1                  9
# 7   3108588        1             8                 1                 14
# 8   2295261        1             9                 1                 16
# 9   2550362        1            10                 4                  8
# 10  1187899        1            11                 4                  8
#
#     days_since_prior_order
# 0                      NaN
# 1                     15.0
# ...

# %%
df_ords['user_id']==1
# Out:
# 0           True
# 1           True
# 2           True
# 3           True
# 4           True
#            ...
# 3421078    False
# 3421079    False
# 3421080    False
# 3421081    False
# 3421082    False
# Name: user_id, Length: 3421083, dtype: bool

# %%
df_user_id.describe()
# Out:
#        user_id  order_number  order-day_of_day  order_hour_of_day  \
# count     11.0     11.000000         11.000000          11.000000
# mean       1.0      6.000000          2.636364          10.090909
# std        0.0      3.316625          1.286291           3.477198
# min        1.0      1.000000          1.000000           7.000000
# 25%        1.0      3.500000          1.500000           7.500000
# 50%        1.0      6.000000          3.000000           8.000000
# 75%        1.0      8.500000          4.000000          13.000000
# max        1.0     11.000000          4.000000          16.000000
#
#        days_since_prior_order
# count               10.000000
# mean                19.000000
# std                  9.030811
# min                  0.000000
# 25%                 14.250000
# 50%                 19.500000
# 75%                 26.250000
# max                 30.000000

# %%
df_ords.to_csv(os.path.join(path,'orders_wrangled.csv'))

# %%
df_prods.to_csv(os.path.join(path,'products_wrangled.csv'))
